# %%
#Libraries
import os
import pydicom
import matplotlib.pyplot as plt
from lungmask import mask
import SimpleITK as sitk

# %%
def get_mask(filename, plot_mask=False, return_val=False):

    input_image = sitk.ReadImage(filename)

   
    
    mask_out = mask.apply(input_image)[0]  #default model is U-net(R231)
    # if plot_mask: 
    #     fig = plt.figure(figsize=(4, 4))
    #     # plt.imshow(mask_out)
        
    #     # plt.imshow(mask_out)
    if return_val:
        return mask_out

# %%
# Set the path to the folder containing the sub folders 
folder_path = 'C:/Users/Nimesha/Documents/MSC_RESEARCH/IMAGES/Support_Set'


# Initialize a figure with a 4x5 grid of subplots
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(16, 12))

for i, sub_folder in enumerate(os.listdir(folder_path)):
    print(sub_folder)
    sub_folder_path = os.path.join(folder_path+'/'+ sub_folder)
    
    for j, dcm_file in enumerate(os.listdir(sub_folder_path)):
        file_path = os.path.join(sub_folder_path+'/'+ dcm_file)
        
        dicom_image = pydicom.dcmread(file_path)
        img = dicom_image.pixel_array

        # Plot the image in the subplot
        axes[i][j].imshow(img, cmap='gray')
        axes[i][j].axis('off')
        axes[i][j].set_title(dcm_file)

plt.tight_layout()
plt.show()
# Out:
# Stage_A
# Stage_B
# Stage_E
# Stage_G

# %%
# Set the path to the folder containing the sub folders 
folder_path = 'C:/Users/Nimesha/Documents/MSC_RESEARCH/IMAGES/Support_Set'


# Initialize a figure with a 4x5 grid of subplots
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(16, 12))

for i, sub_folder in enumerate(os.listdir(folder_path)):
    print(sub_folder)
    sub_folder_path = os.path.join(folder_path+'/'+ sub_folder)
    
    for j, dcm_file in enumerate(os.listdir(sub_folder_path)):
        file_path = os.path.join(sub_folder_path+'/'+ dcm_file)
        
        dicom_image = pydicom.dcmread(file_path)
        img = dicom_image.pixel_array
        

        

        

        masked_img=get_mask(file_path,plot_mask=True,return_val=True)

        mask_on_orginal = img*masked_img

        # Plot the image in the subplot
        axes[i][j].imshow(mask_on_orginal, cmap='gray')
        axes[i][j].axis('off')
        axes[i][j].set_title(dcm_file)

plt.tight_layout()
plt.show()
# Out:
# Stage_A
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.86it/s]
# 100%|██████████| 2/2 [00:00<00:00, 2000.14it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.90it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.77it/s]
# 100%|██████████| 3/3 [00:00<?, ?it/s]
# Stage_B
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.90it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.90it/s]
# 100%|██████████| 6/6 [00:00<00:00, 6000.43it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.90it/s]
# 100%|██████████| 2/2 [00:00<00:00, 1999.67it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.85it/s]
# 100%|██████████| 2/2 [00:00<00:00, 2001.10it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.97it/s]
# 100%|██████████| 2/2 [00:00<00:00, 2000.62it/s]
# Stage_E
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]
# 100%|██████████| 3/3 [00:00<?, ?it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.97it/s]
# 100%|██████████| 2/2 [00:00<00:00, 1999.67it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.96it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.86it/s]
# 100%|██████████| 4/4 [00:00<00:00, 3997.43it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# Stage_G
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# 100%|██████████| 10/10 [00:00<00:00, 9979.31it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.97it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.89it/s]
# 100%|██████████| 2/2 [00:00<00:00, 1999.67it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.93it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
# INFO:root:No GPU support available, will use CPU. Note, that this is significantly slower!
# 100%|██████████| 1/1 [00:00<00:00,  1.77it/s]
# 100%|██████████| 2/2 [00:00<?, ?it/s]
